# %% [markdown]
# # import library

# %%
import pandas as pd
pd.set_option('display.max_columns', 100)

import requests
import json

import re

from pprint import pprint

# %% [markdown]
# # fips and label lists

# %% [markdown]
# ## get fips list of all counties in CA

# %%
fips_ep_url = "https://www2.census.gov/geo/docs/reference/codes/files/st06_ca_cou.txt"

fips_txt = requests.get(fips_ep_url).text

fips_lines = fips_txt.split("\r\n")
fips_lines[:5]

fips_ls = []

for line in fips_lines:
    fips_ls.append(line.split(","))
    
fips_ls[:5]

fips_df = pd.DataFrame(fips_ls)
fips_df.drop([0, 1, 4], inplace=True, axis = 1)
fips_df.columns = ["fips", "county"]
fips_df.head()
# Out:
#   fips            county
# 0  001    Alameda County
# 1  003     Alpine County
# 2  005     Amador County
# 3  007      Butte County
# 4  009  Calaveras County

# %% [markdown]
# ## get list of label id and names

# %%
label_ep_url = "https://api.census.gov/data/2017/acs/acs5/variables"
label_txt = requests.get(label_ep_url).text
label_ls = json.loads(label_txt)

label_dict = {}

for row in label_ls:
    label_dict[row[0]] = row[1]

label_df = pd.DataFrame(label_ls[1:], columns = label_ls[0])
label_df.head()
# Out:
#              name                                              label  \
# 0             for                       Census API FIPS 'for' clause
# 1              in                        Census API FIPS 'in' clause
# 2           ucgid         Uniform Census Geography Identifier clause
# 3  B06004HPR_002E               Estimate!!Total!!Born in Puerto Rico
# 4     B02019_008E  Estimate!!Total Groups Tallied!!Micronesian!!O...
#
#                                              concept
# 0                 Census API Geography Specification
# 1                 Census API Geography Specification
# 2                 Census API Geography Specification
# 3  PLACE OF BIRTH (WHITE ALONE, NOT HISPANIC OR L...
# 4  NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALO...

# %% [markdown]
# # census

# %% [markdown]
# ## get block group data from us census API

# %%
c_fips_ls = list(fips_df["fips"])

cs_ls = []

for c_fips in c_fips_ls[:1]:

    cs_ep_url = "https://api.census.gov/data/2017/acs/acs5?" \
             "get=group(B05001),NAME&" \
             "for=block%20group:*&in=state:06+in=county:" + c_fips + "&" \
             "key=9e518d813c34cefe46bf0317ca1b54e57d30219a"

    cs_txt = requests.get(cs_ep_url).text
    cs_js = json.loads(cs_txt)
    
    cs_ls.extend(cs_js)
    
    print("fips {} : {}".format(c_fips, len(cs_ls)))

cs_df = pd.DataFrame(cs_ls[1:], columns = cs_ls[0])
cs_df.head()
# Out:
# fips 001 : 1048
#                                                 NAME                 GEO_ID  \
# 0  Block Group 1, Census Tract 4403.36, Alameda C...  1500000US060014403361
# 1  Block Group 2, Census Tract 4403.36, Alameda C...  1500000US060014403362
# 2  Block Group 1, Census Tract 4419.27, Alameda C...  1500000US060014419271
# 3  Block Group 2, Census Tract 4419.27, Alameda C...  1500000US060014419272
# 4  Block Group 1, Census Tract 4419.25, Alameda C...  1500000US060014419251
#
#   B05001_001E B05001_001M B05001_002E B05001_002M B05001_003E B05001_003M  \
# 0        None        None        None        None        None        None
# 1        None        None        None        None        None        None
# 2        None        None        None        None        None        None
# 3        None        None        None        None        None        None
# 4        None        None        None        None        None        None
#
#   B05001_004E B05001_004M B05001_005E B05001_005M B05001_006E B05001_006M  \
# 0        None        None        None        None        None        None
# 1        None        None        None        None        None        None
# 2        None        None        None        None        None        None
# 3        None        None        None        None        None        None
# 4        None        None        None        None        None        None
#
#                                                 NAME B05001_001EA  \
# 0  Block Group 1, Census Tract 4403.36, Alameda C...         None
# 1  Block Group 2, Census Tract 4403.36, Alameda C...         None
# 2  Block Group 1, Census Tract 4419.27, Alameda C...         None
# 3  Block Group 2, Census Tract 4419.27, Alameda C...         None
# 4  Block Group 1, Census Tract 4419.25, Alameda C...         None
#
#   B05001_001MA B05001_002EA B05001_002MA B05001_003MA B05001_003EA  \
# 0         None         None         None         None         None
# 1         None         None         None         None         None
# 2         None         None         None         None         None
# 3         None         None         None         None         None
# 4         None         None         None         None         None
#
#   B05001_004EA B05001_004MA B05001_005MA B05001_005EA B05001_006EA  \
# 0         None         None         None         None         None
# 1         None         None         None         None         None
# 2         None         None         None         None         None
# 3         None         None         None         None         None
# 4         None         None         None         None         None
#
#   B05001_006MA state county   tract block group
# 0         None    06    001  440336           1
# 1         None    06    001  440336           2
# 2         None    06    001  441927           1
# 3         None    06    001  441927           2
# 4         None    06    001  441925           1

# %% [markdown]
# ## get tract data from us census API

# %%
cs_ls = []

cs_ep_url = "https://api.census.gov/data/2017/acs/acs5?" \
             "get=group(B05001)&" \
             "for=tract:*&in=state:06+in=county:*&" \
             "key=9e518d813c34cefe46bf0317ca1b54e57d30219a"

cs_txt = requests.get(cs_ep_url).text
cs_js = json.loads(cs_txt)
    
cs_ls.extend(cs_js)

cs_df = pd.DataFrame(cs_ls[1:], columns = cs_ls[0])
cs_df.dropna(axis = 1, inplace=True)
cs_cols_to_drop = [col for col in list(cs_df.columns) if re.match(".*M$", col)]
cs_df.drop(labels = cs_cols_to_drop, inplace=True, axis = 1)
cs_df.head()
# Out:
#                  GEO_ID B05001_001E B05001_002E B05001_003E B05001_004E  \
# 0  1400000US06001400100        2991        2033          11          46
# 1  1400000US06001400200        1997        1668          11          38
# 2  1400000US06001400300        5123        4241          13          78
# 3  1400000US06001400400        3991        3336           0          79
# 4  1400000US06001400500        3944        3258           0         111
#
#   B05001_005E B05001_006E                                           NAME  \
# 0         653         248  Census Tract 4001, Alameda County, California
# 1         158         122  Census Tract 4002, Alameda County, California
# 2         539         252  Census Tract 4003, Alameda County, California
# 3         301         275  Census Tract 4004, Alameda County, California
# 4         228         347  Census Tract 4005, Alameda County, California
#
#   state county   tract
# 0    06    001  400100
# 1    06    001  400200
# 2    06    001  400300
# 3    06    001  400400
# 4    06    001  400500

# %%
cs_cols = cs_df.columns

cs_cols_conv = []

for col in cs_cols:
    try:
        cs_cols_conv.append(label_dict[col])
    except:
        cs_cols_conv.append(col)

cs_df.columns = cs_cols_conv

cs_df.head()
# Out:
#               Geography Estimate!!Total  \
# 0  1400000US06001400100            2991
# 1  1400000US06001400200            1997
# 2  1400000US06001400300            5123
# 3  1400000US06001400400            3991
# 4  1400000US06001400500            3944
#
#   Estimate!!Total!!U.S. citizen born in the United States  \
# 0                                               2033
# 1                                               1668
# 2                                               4241
# 3                                               3336
# 4                                               3258
#
#   Estimate!!Total!!U.S. citizen born in Puerto Rico or U.S. Island Areas  \
# 0                                                 11
# 1                                                 11
# 2                                                 13
# 3                                                  0
# 4                                                  0
#
#   Estimate!!Total!!U.S. citizen born abroad of American parent(s)  \
# 0                                                 46
# 1                                                 38
# 2                                                 78
# 3                                                 79
# 4                                                111
#
#   Estimate!!Total!!U.S. citizen by naturalization  \
# 0                                             653
# 1                                             158
# 2                                             539
# 3                                             301
# 4                                             228
#
#   Estimate!!Total!!Not a U.S. citizen  \
# 0                                 248
# 1                                 122
# 2                                 252
# 3                                 275
# 4                                 347
#
#                                             NAME state county   tract
# 0  Census Tract 4001, Alameda County, California    06    001  400100
# 1  Census Tract 4002, Alameda County, California    06    001  400200
# 2  Census Tract 4003, Alameda County, California    06    001  400300
# 3  Census Tract 4004, Alameda County, California    06    001  400400
# 4  Census Tract 4005, Alameda County, California    06    001  400500

# %%
cs_df.to_csv("data/acs2017_tract.csv")
